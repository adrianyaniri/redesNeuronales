# %%
from utils.get_perceptron_line import get_perceptron_line
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score
from models.perceptron import Perceptron
from sklearn.model_selection import train_test_split
from function.generate_data import datos_xor, datos_linealmente_seprables
import numpy as np

np.random.seed(42)

# Generar conjunto de datos
X_lineal, y_lineal = datos_linealmente_seprables(200, 4)

# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_lineal, y_lineal, test_size=0.2)

perceptron = Perceptron(n_epochs=1000)
perceptron.train(X_train, y_train)
y_pred = perceptron.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

w = perceptron.weights
b = perceptron.bias

plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='bwr')
x_min, x_max, y_min, y_max = get_perceptron_line(w, b)

plt.plot([x_min, x_max], [y_min, y_max], 'r-')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

print(f'Accuracy on test set: {accuracy}')
# Out:
# Accuracy on test set: 0.975

# %%
from utils.get_perceptron_line import get_perceptron_line
from matplotlib import pyplot as plt
from sklearn.metrics import accuracy_score
from models.perceptron import Perceptron
from sklearn.model_selection import train_test_split
from function.generate_data import datos_xor, datos_linealmente_seprables
import numpy as np

np.random.seed(42)

# Generar conjunto de datos
X_xor, y_xor = datos_xor(20, 2)


# Dividir el conjunto de datos en entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X_xor, y_xor, test_size=0.2)

perceptron = Perceptron(n_epochs=1000)
perceptron.train(X_train, y_train)
y_pred = perceptron.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)

w = perceptron.weights
b = perceptron.bias

plt.scatter(X_train[:, 0], X_train[:, 1], c=y_train, cmap='bwr')
x_min, x_max, y_min, y_max = get_perceptron_line(w, b)

plt.plot([x_min, x_max], [y_min, y_max], 'r-')
plt.xlabel('x1')
plt.ylabel('x2')
plt.show()

print(f'Accuracy on test set: {accuracy}')
# Out:
# Accuracy on test set: 0.5
